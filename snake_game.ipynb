# %%
import pygame
import time
import random

#initial game variables

# Window size
frame_size_x = 720
frame_size_y = 480

#Parameters for Snake
snake_pos = [100, 50]
snake_body = [[100, 50], [100-10, 50], [100-(2*10), 50]]
direction = 'RIGHT'
change_to = direction

#Parameters for food
food_pos = [0,0]
food_spawn = True

score = 0

black = (0, 0, 0)
white = (255, 255, 255)
red = (255, 0, 0)
green = (0, 255, 0)

# Initialise game window
pygame.init()
pygame.display.set_caption('Snake Eater')
game_window = pygame.display.set_mode((frame_size_x, frame_size_y))


# FPS (frames per second) controller to set the speed of the game
fps_controller = pygame.time.Clock()

food_pos = [random.randrange(1, (frame_size_x//10)) * 10, random.randrange(1, (frame_size_y//10)) * 10]


def check_for_events():
    """
    This should contain the main for loop (listening for events). You should close the program when
    someone closes the window, update the direction attribute after input from users. You will have to make sure
    snake cannot reverse the direction i.e. if it turned left it cannot move right next.
    """
    global change_to,direction
    
    for event in pygame.event.get():
        if event.type == pygame.KEYDOWN:
            if event.key == pygame.K_UP:
                change_to = 'UP'
            if event.key == pygame.K_DOWN:
                change_to = 'DOWN'
            if event.key == pygame.K_LEFT:
                change_to = 'LEFT'
            if event.key == pygame.K_RIGHT:
                change_to = 'RIGHT'
  
    if change_to == 'UP' and direction != 'DOWN':
        direction = 'UP'
    if change_to == 'DOWN' and direction != 'UP':
        direction = 'DOWN'
    if change_to == 'LEFT' and direction != 'RIGHT':
        direction = 'LEFT'
    if change_to == 'RIGHT' and direction != 'LEFT':
        direction = 'RIGHT'
      
            
def update_snake():
    """
     This should contain the code for snake to move, grow, detect walls etc.
     """
    global score,food_spawn
    # Code for making the snake move in the expected direction
    
    if direction == 'UP':
        snake_pos[1] -= 10
    if direction == 'DOWN':
        snake_pos[1] += 10
    if direction == 'LEFT':
        snake_pos[0] -= 10
    if direction == 'RIGHT':
        snake_pos[0] += 10

    # Make the snake's body respond after the head moves. The responses will be different if it eats the food.
    # Note you cannot directly use the functions for detecting collisions 
    # since we have not made snake and food as a specific sprite or surface.
    
    snake_body.insert(0, list(snake_pos))
    if snake_pos[0] == food_pos[0] and snake_pos[1] == food_pos[1]:
        score += 1
        food_spawn = True
    else:
        snake_body.pop()

    # End the game if the snake collides with the wall or with itself. 
    
    if snake_pos[0] < 0 or snake_pos[0] > frame_size_x-10 or snake_pos[1] < 0 or snake_pos[1] > frame_size_y-10:
        game_over()
  
    for block in snake_body[1:]:
        if snake_pos[0] == block[0] and snake_pos[1] == block[1]:
            game_over()
            

def create_food():
    """ 
    This function should set coordinates of food if not there on the screen. You can use randrange() to generate
    the location of the food.
    """
    global food_spawn,food_pos
    
    if food_spawn:
        food_pos = [random.randrange(10, (frame_size_x//10)-1) * 10, random.randrange(10, (frame_size_y//10)-10) * 10]
        
    food_spawn = False
    

def show_score(pos, color, font, size ):
    """
    It takes in the above arguements and shows the score at the given pos according to the color, font and size.
    """
    score_font = pygame.font.SysFont(font, size)
    score_text = score_font.render(f'Score : {score}', 1, color)
    game_window.blit(score_text,pos)
    

def update_screen():
    """
    Draw the snake, food, background, score on the screen
    """
    game_window.fill(black)
    
    for pos in snake_body:
        pygame.draw.rect(game_window, green,pygame.Rect(pos[0], pos[1], 10, 10))
        
    pygame.draw.rect(game_window, white, pygame.Rect(food_pos[0], food_pos[1], 10, 10))

def game_over():
    """ 
    Write the function to call in the end. 
    It should write game over on the screen, show your score, wait for 3 seconds and then exit
    """
    big_font = pygame.font.SysFont('times new roman', 50)
    small_font = pygame.font.SysFont('times new roman', 20)
    end_text = big_font.render( 'YOU DIED', 1, red)
    score_text = small_font.render( f'Score: {score}' , 1, red)
    game_window.blit(score_text, (frame_size_x/2 - score_text.get_width()/2, 390))
    game_window.blit(end_text, (frame_size_x/2 - end_text.get_width()/2, 190))
    pygame.display.flip()
    time.sleep(2)
    pygame.quit() 
    quit()


# Main loop
    # Make appropriate calls to the above functions so that the game could finally run

run = True    

while run:
        
    check_for_events()
    update_snake()
    create_food()
    update_screen()
      
    show_score((10,10), white, 'times new roman', 20)
    
    pygame.display.update()
    
    for event in pygame.event.get():
        if event.type == pygame.QUIT:
            pygame.quit()
            quit()
    
    fps_controller.tick(15)
# Out:
# pygame 2.0.1 (SDL 2.0.14, Python 3.8.8)
# Hello from the pygame community. https://www.pygame.org/contribute.html
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-6ffa3e59e490> in <module>
#     164     update_snake()
#     165     create_food()
# --> 166     update_screen()
#     167
#     168     show_score((10,10), white, 'times new roman', 20)
#
# <ipython-input-1-6ffa3e59e490> in update_screen()
#     130     Draw the snake, food, background, score on the screen
#     131     """
# --> 132     game_window.fill(black)
#     133
#     134     for pos in snake_body:
#
# error: display Surface quit
